# %%
import nltk

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *

# %%
text1.similar("whale")
# Out:
# ship boat sea time captain world man deck pequod other whales air
# water head crew line thing side way body

# %%
text1.common_contexts(["whale", "great"])
# Out:
# the_and a_ship the_chapter a_fish the_hunting the_who the_head

# %%
text1.dispersion_plot(["whale", "Ahab", "Pequod", "revenge", "death", "leg"])

# %%
text1.concordance("revenge")
# Out:
# Displaying 8 of 8 matches:
# had taken our oaths of violence and revenge . For some time past , though at in
# us , immitigable , and supernatural revenge . Here , then , was this grey - hea
# ality to help him to his monomaniac revenge . How it was that they so abounding
# f his companions , as if fired with revenge for their sufferings ." Again : " A
# g wreck , and THE HORRID ASPECT AND REVENGE OF THE WHALE , wholly engrossed my
# ncerning his own proper and private revenge upon the man who had stung him in t
# ystematically built the plan of his revenge . " During the night , Radney had a
#  deed he had planned . Yet complete revenge he had , and without being the aven

# %%
ftext1 = FreqDist(text1)
ftext1.most_common(75)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624),
#  ('The', 612),
#  ('their', 612),
#  ('are', 586),
#  ('they', 586),
#  ('an', 582),
#  ('some', 578),
#  ('then', 571),
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 20)) 

ftext1.plot(75, cumulative=True)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Cumulative Counts'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 20)) 
text2.dispersion_plot(["Elinor", "Marianne", "Edward", "Willoughby"])

# %%
print(text5)
text5.collocation_list()
# Out:
# <Text: Chat Corpus>
# [('wanna', 'chat'),
#  ('PART', 'JOIN'),
#  ('MODE', '#14-19teens'),
#  ('JOIN', 'PART'),
#  ('PART', 'PART'),
#  ('cute.-ass', 'MP3'),
#  ('MP3', 'player'),
#  ('JOIN', 'JOIN'),
#  ('times', '.. .'),
#  ('ACTION', 'watches'),
#  ('guys', 'wanna'),
#  ('song', 'lasts'),
#  ('last', 'night'),
#  ('ACTION', 'sits'),
#  ('-...)...-', 'S.M.R.'),
#  ('Lime', 'Player'),
#  ('Player', '12%'),
#  ('dont', 'know'),
#  ('lez', 'gurls'),
#  ('long', 'time')]

# %%
four_letter_words = [word for word in text5 if len(word) == 4]
plt.figure(figsize=(30, 20)) 
fdist5 = FreqDist(four_letter_words)
fdist5.most_common()
# fdist5.plot()
# print(four_letter_words)
# Out:
# [('JOIN', 1021),
#  ('PART', 1016),
#  ('that', 274),
#  ('what', 183),
#  ('here', 181),
#  ('....', 170),
#  ('have', 164),
#  ('like', 156),
#  ('with', 152),
#  ('chat', 142),
#  ('your', 137),
#  ('good', 130),
#  ('just', 125),
#  ('lmao', 107),
#  ('know', 103),
#  ('room', 98),
#  ('from', 92),
#  ('this', 86),
#  ('well', 81),
#  ('back', 78),
#  ('hiya', 78),
#  ('they', 77),
#  ('dont', 75),
#  ('yeah', 75),
#  ('want', 71),
#  ('love', 60),
#  ('guys', 58),
#  ('some', 58),
#  ('been', 57),
#  ('talk', 56),
#  ('nice', 52),
#  ('time', 50),
#  ('when', 48),
#  ('haha', 44),
#  ('make', 44),
#  ('girl', 43),
#  ('need', 43),
#  ('U122', 42),
#  ('MODE', 41),
#  ('will', 40),
#  ('much', 40),
#  ('then', 40),
#  ('over', 39),
#  ('work', 38),
#  ('were', 38),
#  ('take', 37),
#  ('U121', 36),
#  ('U115', 36),
#  ('song', 36),
#  ('even', 35),
#  ('does', 35),
#  ('seen', 35),
#  ('U156', 35),
#  ('U105', 35),
#  ('more', 34),
#  ('damn', 34),
#  ('only', 33),
# ...
