# %% [markdown]
# # Week 1

# %% [markdown]
# ## Exercises
#
# What is the difference between html and wiki-source?
# - The html is formatted by the browser to display the content in a certain way, and makes the markup tags invisible to the user. The wiki source is plain text with visible markup tags.
#
# What are the parameters you can set for a query of the wikipedia API?
# - you can query any wikipedia content based on their identifier, of which there is a long list, or create and edit them among a long list of other actions. You can specify the format of the data you query and filter on lots of metadata that is not visible on the wiki pages.

# %%
import requests
response = requests.get("https://wikipedia.org/wiki/Spider-Man")
html = response.text

baseurl = "https://en.wikipedia.org/w/api.php?"

action = "action=query"

title = "titles=rope"

content = "prop=revisions&rvprop=content&rvsection=0"

query = "{}{}&{}&{}".format(baseurl, action, title, content)
reponse = requests.get(query)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Spider-Man - Wikipedia</title>
# ...
